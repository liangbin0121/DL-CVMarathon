# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2

# %%
 import os
 from google.colab import drive 
 drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# %cd '/content/gdrive/My Drive/python_training/DL100_CV/day_44/'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# /content/gdrive/My Drive/python_training/DL100_CV/day_44

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %% [markdown]
# 圖像資料: (2140, 96, 96)
#
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0062 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00222, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00222 to 0.00193, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00186, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 18s 10ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00186 to 0.00182, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00182 to 0.00179, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7958e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00179 to 0.00171, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7584e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00171 to 0.00168, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.7377e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00168 to 0.00158, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.7324e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00158 to 0.00143, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.9900e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00143 to 0.00126, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.4612e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00126 to 0.00117, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.9791e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00117 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.5974e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00111, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 4.3753e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00111 to 0.00103, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.2228e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00103
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9639e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00103 to 0.00102, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7493e-04 - val_loss: 9.9279e-04
#
# Epoch 00017: val_loss improved from 0.00102 to 0.00099, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5729e-04 - val_loss: 9.2758e-04
#
# Epoch 00018: val_loss improved from 0.00099 to 0.00093, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6183e-04 - val_loss: 9.0974e-04
#
# Epoch 00019: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3734e-04 - val_loss: 8.9324e-04
#
# Epoch 00020: val_loss improved from 0.00091 to 0.00089, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2431e-04 - val_loss: 9.0618e-04
#
# Epoch 00021: val_loss did not improve from 0.00089
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0887e-04 - val_loss: 8.6488e-04
#
# Epoch 00022: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9885e-04 - val_loss: 8.9375e-04
#
# Epoch 00023: val_loss did not improve from 0.00086
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8555e-04 - val_loss: 8.3960e-04
#
# Epoch 00024: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7931e-04 - val_loss: 8.8631e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7437e-04 - val_loss: 8.9527e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6999e-04 - val_loss: 8.2773e-04
#
# Epoch 00027: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6024e-04 - val_loss: 8.6211e-04
#
# Epoch 00028: val_loss did not improve from 0.00083
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5521e-04 - val_loss: 8.3990e-04
#
# Epoch 00029: val_loss did not improve from 0.00083
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4617e-04 - val_loss: 8.3171e-04
#
# Epoch 00030: val_loss did not improve from 0.00083
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5243e-04 - val_loss: 8.3535e-04
#
# Epoch 00031: val_loss did not improve from 0.00083
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4468e-04 - val_loss: 8.4109e-04
#
# Epoch 00032: val_loss did not improve from 0.00083
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3235e-04 - val_loss: 8.7689e-04
#
# Epoch 00033: val_loss did not improve from 0.00083
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3295e-04 - val_loss: 8.0868e-04
#
# Epoch 00034: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2683e-04 - val_loss: 8.1204e-04
#
# Epoch 00035: val_loss did not improve from 0.00081
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2517e-04 - val_loss: 7.9813e-04
#
# Epoch 00036: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1782e-04 - val_loss: 7.9085e-04
#
# Epoch 00037: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1810e-04 - val_loss: 7.9257e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1887e-04 - val_loss: 8.3684e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1032e-04 - val_loss: 7.9057e-04
#
# Epoch 00040: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0388e-04 - val_loss: 7.9742e-04
#
# Epoch 00041: val_loss did not improve from 0.00079
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0679e-04 - val_loss: 7.7815e-04
#
# Epoch 00042: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9577e-04 - val_loss: 8.0135e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9643e-04 - val_loss: 8.1919e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9925e-04 - val_loss: 7.8510e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 1.9232e-04 - val_loss: 7.7075e-04
#
# Epoch 00046: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 1.9228e-04 - val_loss: 8.0625e-04
#
# Epoch 00047: val_loss did not improve from 0.00077
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8604e-04 - val_loss: 7.8659e-04
#
# Epoch 00048: val_loss did not improve from 0.00077
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9001e-04 - val_loss: 8.1993e-04
#
# Epoch 00049: val_loss did not improve from 0.00077
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8147e-04 - val_loss: 7.8888e-04
#
# Epoch 00050: val_loss did not improve from 0.00077
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8043e-04 - val_loss: 8.3214e-04
#
# Epoch 00051: val_loss did not improve from 0.00077
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7927e-04 - val_loss: 7.6666e-04
#
# Epoch 00052: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8178e-04 - val_loss: 7.5660e-04
#
# Epoch 00053: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7260e-04 - val_loss: 7.9606e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7074e-04 - val_loss: 7.8466e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7190e-04 - val_loss: 7.9607e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7098e-04 - val_loss: 7.7958e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6809e-04 - val_loss: 8.7249e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7383e-04 - val_loss: 7.7304e-04
#
# Epoch 00059: val_loss did not improve from 0.00076
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6778e-04 - val_loss: 7.6451e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6904e-04 - val_loss: 7.7758e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6041e-04 - val_loss: 7.8464e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6171e-04 - val_loss: 7.7040e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5564e-04 - val_loss: 7.7648e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5467e-04 - val_loss: 7.8988e-04
#
# Epoch 00065: val_loss did not improve from 0.00076
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5347e-04 - val_loss: 8.0646e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5279e-04 - val_loss: 7.9126e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5275e-04 - val_loss: 7.8455e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4840e-04 - val_loss: 8.0999e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4857e-04 - val_loss: 7.7517e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4694e-04 - val_loss: 8.2099e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4921e-04 - val_loss: 7.5118e-04
#
# Epoch 00072: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4584e-04 - val_loss: 8.1148e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4286e-04 - val_loss: 7.5393e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4158e-04 - val_loss: 7.6601e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3946e-04 - val_loss: 8.4528e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4104e-04 - val_loss: 7.8117e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4187e-04 - val_loss: 7.6962e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4131e-04 - val_loss: 7.7901e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3914e-04 - val_loss: 8.1600e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3622e-04 - val_loss: 7.8903e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3282e-04 - val_loss: 7.8899e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3287e-04 - val_loss: 7.3407e-04
#
# Epoch 00083: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3193e-04 - val_loss: 7.8958e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3757e-04 - val_loss: 8.0200e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2830e-04 - val_loss: 7.6791e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3272e-04 - val_loss: 7.6009e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2874e-04 - val_loss: 7.6921e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2939e-04 - val_loss: 7.6353e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 1.2673e-04 - val_loss: 7.7495e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2134e-04 - val_loss: 8.1825e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2432e-04 - val_loss: 8.1889e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2224e-04 - val_loss: 7.9317e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2064e-04 - val_loss: 7.5253e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2148e-04 - val_loss: 7.8757e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2092e-04 - val_loss: 8.0125e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2011e-04 - val_loss: 7.8953e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1569e-04 - val_loss: 8.0715e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1698e-04 - val_loss: 7.6952e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2018e-04 - val_loss: 8.1400e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2111e-04 - val_loss: 8.4309e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1638e-04 - val_loss: 7.5595e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1386e-04 - val_loss: 7.8590e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1319e-04 - val_loss: 8.0232e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1342e-04 - val_loss: 8.3067e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1226e-04 - val_loss: 7.6757e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1110e-04 - val_loss: 7.7131e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1187e-04 - val_loss: 7.6749e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0910e-04 - val_loss: 7.6991e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0729e-04 - val_loss: 8.1736e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0403e-04 - val_loss: 7.7678e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0860e-04 - val_loss: 7.8198e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0742e-04 - val_loss: 8.0168e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0761e-04 - val_loss: 7.5353e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0172e-04 - val_loss: 7.8162e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0546e-04 - val_loss: 7.6136e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0408e-04 - val_loss: 8.0240e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0527e-04 - val_loss: 8.2155e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0575e-04 - val_loss: 8.0495e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0146e-04 - val_loss: 7.9459e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0212e-04 - val_loss: 7.9784e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0231e-04 - val_loss: 7.8662e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0275e-04 - val_loss: 7.8599e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0297e-04 - val_loss: 7.6413e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0278e-04 - val_loss: 7.6646e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0059e-04 - val_loss: 8.0214e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7326e-05 - val_loss: 7.6847e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6809e-05 - val_loss: 7.8240e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8779e-05 - val_loss: 7.8274e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7369e-05 - val_loss: 8.0102e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7642e-05 - val_loss: 8.2055e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4190e-05 - val_loss: 7.9284e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4281e-05 - val_loss: 7.6171e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 9.9350e-05 - val_loss: 7.6491e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7285e-05 - val_loss: 7.8484e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3822e-05 - val_loss: 7.6181e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3189e-05 - val_loss: 8.1573e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3529e-05 - val_loss: 7.6621e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2047e-05 - val_loss: 8.0123e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0552e-05 - val_loss: 7.8346e-04
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8912e-05 - val_loss: 8.0887e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1880e-05 - val_loss: 7.9221e-04
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1508e-05 - val_loss: 7.5768e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0568e-05 - val_loss: 7.9252e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1796e-05 - val_loss: 7.7352e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8283e-05 - val_loss: 7.8311e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0448e-05 - val_loss: 7.6939e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9434e-05 - val_loss: 7.8242e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8476e-05 - val_loss: 8.0970e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9800e-05 - val_loss: 7.8168e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %% [markdown]
# from keras.models import load_model
#
# model = load_model('best_model.hdf5')
#
# test_preds = model.predict(test_images)

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %%
imgs_test.shape
# Out:
# (1783, 96, 96)

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
#model.load_weights('model.h5')
#model_with_augment.load_weights('weights.h5')

# %%
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
import imgaug.augmenters as iaa
import imgaug.augmenters.flip as flip

# %%
# horizontally
#aug = iaa.Fliplr(1.0) ## 0.0~1.0
#imgs_train_flipplr = flip.fliplr(imgs_train)

# %%
def plot_sample(image, keypoint, axis, title):
    image = image.reshape(96,96)
    axis.imshow(image, cmap='gray')
    axis.scatter(keypoint[0::2], keypoint[1::2], marker='x', s=20)
    plt.title(title)

# %%
horizontal_flip = True ###False
sample_image_index = 20    # Index of sample train image used for visualizing various augmentations

# %%
## imgs_train, points_train
def left_right_flip(images, keypoints):
    flipped_keypoints = []
    flipped_images = np.flip(images, axis=2)   # Flip column-wise (axis=2)
    for idx, sample_keypoints in enumerate(keypoints):
        flipped_keypoints.append([96.-coor if idx%2==0 else coor for idx,coor in enumerate(sample_keypoints)])    # Subtract only X co-ordinates of keypoints from 96 for horizontal flipping
    return flipped_images, flipped_keypoints

if horizontal_flip:
    flipped_train_images, flipped_train_keypoints = left_right_flip(imgs_train, points_train)
    print("Shape of flipped_train_images: {}".format(np.shape(flipped_train_images)))
    print("Shape of flipped_train_keypoints: {}".format(np.shape(flipped_train_keypoints)))
    #train_images = np.concatenate((train_images, flipped_train_images))
    #train_keypoints = np.concatenate((train_keypoints, flipped_train_keypoints))
    train_images = np.concatenate((imgs_train, flipped_train_images))
    train_keypoints = np.concatenate((points_train, flipped_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(flipped_train_images[sample_image_index], flipped_train_keypoints[sample_image_index], axis, "Horizontally Flipped")
# Out:
# Shape of flipped_train_images: (2140, 96, 96)
# Shape of flipped_train_keypoints: (2140, 30)

# %%
## imgs_train , points_train
print("Shape of final train_images: {}".format(np.shape(train_images)))
print("Shape of final train_keypoints: {}".format(np.shape(train_keypoints)))

print("\n org Train Data: ")
fig = plt.figure(figsize=(20,8))
for i in range(10):
    axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    plot_sample(imgs_train[i], points_train[i], axis, "")
plt.show()

if horizontal_flip:
    print("Horizontal Flip Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(flipped_train_images[i], flipped_train_keypoints[i], axis, "")
    plt.show()
# Out:
# Shape of final train_images: (4280, 96, 96)
# Shape of final train_keypoints: (4280, 30)
#
#  org Train Data:
# Horizontal Flip Augmentation:

# %%
# training the model
hist_model_aug = model_with_augment.fit(train_images.reshape(-1, 96, 96, 1), 
                       train_keypoints, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model_with_augment.save_weights('aug_weights.h5')
# save the model
model_with_augment.save('aug_model.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1232.1290 - val_loss: 2024.3121
#
# Epoch 00001: val_loss did not improve from 0.00073
# Epoch 2/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1125.6525 - val_loss: 1992.0490
#
# Epoch 00002: val_loss did not improve from 0.00073
# Epoch 3/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 1064.3895 - val_loss: 1789.3960
#
# Epoch 00003: val_loss did not improve from 0.00073
# Epoch 4/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 853.2938 - val_loss: 2897.9190
#
# Epoch 00004: val_loss did not improve from 0.00073
# Epoch 5/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 663.3865 - val_loss: 3538.1062
#
# Epoch 00005: val_loss did not improve from 0.00073
# Epoch 6/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 497.5496 - val_loss: 3390.2294
#
# Epoch 00006: val_loss did not improve from 0.00073
# Epoch 7/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 394.3094 - val_loss: 3507.6231
#
# Epoch 00007: val_loss did not improve from 0.00073
# Epoch 8/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 303.2965 - val_loss: 2868.4202
#
# Epoch 00008: val_loss did not improve from 0.00073
# Epoch 9/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 232.9451 - val_loss: 2784.8703
#
# Epoch 00009: val_loss did not improve from 0.00073
# Epoch 10/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 163.6351 - val_loss: 3264.3545
#
# Epoch 00010: val_loss did not improve from 0.00073
# Epoch 11/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 134.4510 - val_loss: 3097.3706
#
# Epoch 00011: val_loss did not improve from 0.00073
# Epoch 12/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 102.1674 - val_loss: 3412.5809
#
# Epoch 00012: val_loss did not improve from 0.00073
# Epoch 13/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 91.9528 - val_loss: 3369.5241
#
# Epoch 00013: val_loss did not improve from 0.00073
# Epoch 14/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 70.7957 - val_loss: 3496.6667
#
# Epoch 00014: val_loss did not improve from 0.00073
# Epoch 15/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 59.3225 - val_loss: 3108.0206
#
# Epoch 00015: val_loss did not improve from 0.00073
# Epoch 16/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 45.9123 - val_loss: 3148.1080
#
# Epoch 00016: val_loss did not improve from 0.00073
# Epoch 17/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 38.3693 - val_loss: 3513.3351
#
# Epoch 00017: val_loss did not improve from 0.00073
# Epoch 18/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 35.6315 - val_loss: 3067.7647
#
# Epoch 00018: val_loss did not improve from 0.00073
# Epoch 19/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 32.4706 - val_loss: 3116.7344
#
# Epoch 00019: val_loss did not improve from 0.00073
# Epoch 20/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 29.2671 - val_loss: 3229.9891
#
# Epoch 00020: val_loss did not improve from 0.00073
# Epoch 21/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 22.4986 - val_loss: 3214.6507
#
# Epoch 00021: val_loss did not improve from 0.00073
# Epoch 22/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 20.2541 - val_loss: 3254.6654
#
# Epoch 00022: val_loss did not improve from 0.00073
# Epoch 23/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 21.6790 - val_loss: 3281.1835
#
# Epoch 00023: val_loss did not improve from 0.00073
# Epoch 24/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 21.0863 - val_loss: 3208.4105
#
# Epoch 00024: val_loss did not improve from 0.00073
# Epoch 25/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 16.7047 - val_loss: 3202.2037
#
# Epoch 00025: val_loss did not improve from 0.00073
# Epoch 26/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 17.9614 - val_loss: 3277.9700
#
# Epoch 00026: val_loss did not improve from 0.00073
# Epoch 27/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 16.7105 - val_loss: 3089.1568
#
# Epoch 00027: val_loss did not improve from 0.00073
# Epoch 28/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 16.1014 - val_loss: 3287.0245
#
# Epoch 00028: val_loss did not improve from 0.00073
# Epoch 29/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.6660 - val_loss: 3182.2905
#
# Epoch 00029: val_loss did not improve from 0.00073
# Epoch 30/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.4246 - val_loss: 3262.7348
#
# Epoch 00030: val_loss did not improve from 0.00073
# Epoch 31/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 15.7705 - val_loss: 3192.4144
#
# Epoch 00031: val_loss did not improve from 0.00073
# Epoch 32/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 15.9734 - val_loss: 3165.4419
#
# Epoch 00032: val_loss did not improve from 0.00073
# Epoch 33/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.3565 - val_loss: 3326.6982
#
# Epoch 00033: val_loss did not improve from 0.00073
# Epoch 34/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 13.5654 - val_loss: 3194.2417
#
# Epoch 00034: val_loss did not improve from 0.00073
# Epoch 35/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 15.2442 - val_loss: 3086.5633
#
# Epoch 00035: val_loss did not improve from 0.00073
# Epoch 36/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 17.4968 - val_loss: 3194.7385
#
# Epoch 00036: val_loss did not improve from 0.00073
# Epoch 37/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 13.4794 - val_loss: 3273.1701
#
# Epoch 00037: val_loss did not improve from 0.00073
# Epoch 38/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.2835 - val_loss: 3162.0075
#
# Epoch 00038: val_loss did not improve from 0.00073
# Epoch 39/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 15.7948 - val_loss: 3313.4022
#
# Epoch 00039: val_loss did not improve from 0.00073
# Epoch 40/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 13.1346 - val_loss: 3264.2513
#
# Epoch 00040: val_loss did not improve from 0.00073
# Epoch 41/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 12.7694 - val_loss: 3273.6340
#
# Epoch 00041: val_loss did not improve from 0.00073
# Epoch 42/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 12.2339 - val_loss: 3295.6634
#
# Epoch 00042: val_loss did not improve from 0.00073
# Epoch 43/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.2195 - val_loss: 3345.5158
#
# Epoch 00043: val_loss did not improve from 0.00073
# Epoch 44/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.8110 - val_loss: 3120.9983
#
# Epoch 00044: val_loss did not improve from 0.00073
# Epoch 45/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.9445 - val_loss: 3251.4352
#
# Epoch 00045: val_loss did not improve from 0.00073
# Epoch 46/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.3428 - val_loss: 3087.7630
#
# Epoch 00046: val_loss did not improve from 0.00073
# Epoch 47/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.4649 - val_loss: 3152.3400
#
# Epoch 00047: val_loss did not improve from 0.00073
# Epoch 48/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 12.5067 - val_loss: 3310.1035
#
# Epoch 00048: val_loss did not improve from 0.00073
# Epoch 49/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.7545 - val_loss: 3168.0398
#
# Epoch 00049: val_loss did not improve from 0.00073
# Epoch 50/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.8319 - val_loss: 3066.5294
#
# Epoch 00050: val_loss did not improve from 0.00073
# Epoch 51/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.2114 - val_loss: 3185.8312
#
# Epoch 00051: val_loss did not improve from 0.00073
# Epoch 52/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.0056 - val_loss: 3144.0526
#
# Epoch 00052: val_loss did not improve from 0.00073
# Epoch 53/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 9.9612 - val_loss: 3224.4465
#
# Epoch 00053: val_loss did not improve from 0.00073
# Epoch 54/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6276 - val_loss: 3175.3796
#
# Epoch 00054: val_loss did not improve from 0.00073
# Epoch 55/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.5618 - val_loss: 3143.0210
#
# Epoch 00055: val_loss did not improve from 0.00073
# Epoch 56/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.3280 - val_loss: 3233.4272
#
# Epoch 00056: val_loss did not improve from 0.00073
# Epoch 57/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9822 - val_loss: 3090.8648
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.7287 - val_loss: 3174.5777
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.4467 - val_loss: 3271.3344
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.9256 - val_loss: 3209.1769
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.2408 - val_loss: 3274.0424
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.9562 - val_loss: 2976.2820
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.9922 - val_loss: 3187.4296
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.7306 - val_loss: 3420.7081
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9616 - val_loss: 3143.2443
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6294 - val_loss: 3161.4403
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.5817 - val_loss: 3248.0972
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.6471 - val_loss: 3122.0132
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2125 - val_loss: 3234.5761
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.2872 - val_loss: 3125.6397
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 21.3720 - val_loss: 3891.3324
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 108.3217 - val_loss: 3537.9208
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 43.3706 - val_loss: 2979.4184
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 17.9949 - val_loss: 3182.1300
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 13.5228 - val_loss: 3335.9861
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.2486 - val_loss: 3245.4569
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.1879 - val_loss: 3075.9075
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.3785 - val_loss: 3171.4597
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2130 - val_loss: 3226.2729
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6587 - val_loss: 3137.8096
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.5324 - val_loss: 3157.9226
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2234 - val_loss: 3100.8686
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.3734 - val_loss: 3093.0890
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.8640 - val_loss: 3087.8115
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.6641 - val_loss: 3098.2602
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7259 - val_loss: 3089.7484
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.0311 - val_loss: 3137.6983
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.1154 - val_loss: 3115.8504
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.1293 - val_loss: 3298.0582
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1406 - val_loss: 3161.2251
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1068 - val_loss: 3171.0254
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.2842 - val_loss: 3103.8126
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.3199 - val_loss: 3169.0015
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.0266 - val_loss: 3116.9020
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.0253 - val_loss: 3213.4626
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 3424/3424 [==============================] - 29s 8ms/step - loss: 7.9108 - val_loss: 3177.3541
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 3424/3424 [==============================] - 30s 9ms/step - loss: 8.7735 - val_loss: 3203.6768
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.1194 - val_loss: 3220.4409
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 9.2054 - val_loss: 3059.8847
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 11.3303 - val_loss: 3135.5461
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.5880 - val_loss: 3098.4179
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.3887 - val_loss: 3057.8426
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.6820 - val_loss: 3151.4600
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.5937 - val_loss: 3164.3263
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.9209 - val_loss: 3068.1190
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.2827 - val_loss: 3073.1088
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.4048 - val_loss: 3186.4339
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.2121 - val_loss: 3134.6757
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9915 - val_loss: 3057.1514
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.0783 - val_loss: 3159.0742
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1512 - val_loss: 3072.1503
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6470 - val_loss: 3088.4460
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.2230 - val_loss: 3143.3459
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1950 - val_loss: 3001.5492
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1099 - val_loss: 3044.3731
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.2368 - val_loss: 3208.2953
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.5996 - val_loss: 3091.5063
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 7.2001 - val_loss: 3136.6040
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.6948 - val_loss: 3160.0589
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.9876 - val_loss: 3151.9554
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.0434 - val_loss: 3079.7561
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.2323 - val_loss: 3285.1593
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.0210 - val_loss: 3064.0046
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.4405 - val_loss: 3153.4281
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.8503 - val_loss: 3097.5950
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.9649 - val_loss: 3430.4913
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 14.9292 - val_loss: 2984.3666
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 19.7033 - val_loss: 3276.9334
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 10.2878 - val_loss: 3253.9593
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 8.1846 - val_loss: 3243.2026
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.0524 - val_loss: 3140.8055
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.3211 - val_loss: 3143.5123
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.8939 - val_loss: 3080.2425
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.4275 - val_loss: 3173.0826
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.7260 - val_loss: 3200.8035
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.9744 - val_loss: 3250.6517
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.4541 - val_loss: 3083.9609
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.4848 - val_loss: 3109.7645
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.7635 - val_loss: 3084.0992
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 6.5820 - val_loss: 3137.6490
#
# Epoch 00140: val_loss did not improve from 0.00073
# Epoch 141/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.6061 - val_loss: 3029.4266
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.8346 - val_loss: 3089.9194
#
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.6196 - val_loss: 3162.9011
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.4276 - val_loss: 3095.6225
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 7.3387 - val_loss: 2968.3816
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.8246 - val_loss: 3098.2420
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.2451 - val_loss: 3160.0526
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.6635 - val_loss: 3124.0664
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 5.8519 - val_loss: 3038.6419
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 6.9730 - val_loss: 2973.0723
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 aug_dataset testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
aug_points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(aug_points_test[i]))
